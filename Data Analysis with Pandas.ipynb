# %%
import pandas as pd 
import numpy as np

# %%
reviews = pd.read_csv("C:\\Users\\fishk\\Documents\\School Work\\Year 4\\Semester One\\Artificial Neural Networks and Pattern Recognition\\wine reviews.csv", index_col=0)

# %%
reviews
# Out:
#             country                                        description  \
# 0             Italy  Aromas include tropical fruit, broom, brimston...
# 1          Portugal  This is ripe and fruity, a wine that is smooth...
# 2                US  Tart and snappy, the flavors of lime flesh and...
# 3                US  Pineapple rind, lemon pith and orange blossom ...
# 4                US  Much like the regular bottling from 2012, this...
# 5             Spain  Blackberry and raspberry aromas show a typical...
# 6             Italy  Here's a bright, informal red that opens with ...
# 7            France  This dry and restrained wine offers spice in p...
# 8           Germany  Savory dried thyme notes accent sunnier flavor...
# 9            France  This has great depth of flavor with its fresh ...
# 10               US  Soft, supple plum envelopes an oaky structure ...
# 11           France  This is a dry wine, very spicy, with a tight, ...
# ...

# %%
reviews[0:10:2]
# Out:
#    country                                        description  \
# 0    Italy  Aromas include tropical fruit, broom, brimston...
# 2       US  Tart and snappy, the flavors of lime flesh and...
# 4       US  Much like the regular bottling from 2012, this...
# 6    Italy  Here's a bright, informal red that opens with ...
# 8  Germany  Savory dried thyme notes accent sunnier flavor...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 2                                 NaN      87   14.0             Oregon
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 6                             Belsito      87   16.0  Sicily & Sardinia
# 8                               Shine      87   12.0        Rheinhessen
#
#             region_1           region_2         taster_name  \
# 0               Etna                NaN       Kerin O’Keefe
# ...

# %%
reviews.iloc[:5]
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
reviews.loc[:5]
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
# 5     Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 5                        Ars In Vitro      87   15.0     Northern Spain
#
# ...

# %%
reviews.country.loc[:5]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# 3          US
# 4          US
# 5       Spain
# Name: country, dtype: object

# %%
reviews[["country", "price","title"]].iloc[:10]
# Out:
#     country  price                                              title
# 0     Italy    NaN                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1  Portugal   15.0      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2        US   14.0      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3        US   13.0  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4        US   65.0  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 5     Spain   15.0  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
# 6     Italy   16.0   Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# 7    France   24.0              Trimbach 2012 Gewurztraminer (Alsace)
# 8   Germany   12.0  Heinz Eifel 2013 Shine Gewürztraminer (Rheinhe...
# 9    France   27.0  Jean-Baptiste Adam 2012 Les Natures Pinot Gris...

# %%
reviews.loc[:9,["country","price","title"]]
# Out:
#     country  price                                              title
# 0     Italy    NaN                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1  Portugal   15.0      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2        US   14.0      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3        US   13.0  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4        US   65.0  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 5     Spain   15.0  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
# 6     Italy   16.0   Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# 7    France   24.0              Trimbach 2012 Gewurztraminer (Alsace)
# 8   Germany   12.0  Heinz Eifel 2013 Shine Gewürztraminer (Rheinhe...
# 9    France   27.0  Jean-Baptiste Adam 2012 Les Natures Pinot Gris...

# %%
reviews.iloc[:10,[0,2,5]]
#iloc cannot pass a string as a parameter. column indeces are used instead
# Out:
#     country                         designation           province
# 0     Italy                        Vulkà Bianco  Sicily & Sardinia
# 1  Portugal                            Avidagos              Douro
# 2        US                                 NaN             Oregon
# 3        US                Reserve Late Harvest           Michigan
# 4        US  Vintner's Reserve Wild Child Block             Oregon
# 5     Spain                        Ars In Vitro     Northern Spain
# 6     Italy                             Belsito  Sicily & Sardinia
# 7    France                                 NaN             Alsace
# 8   Germany                               Shine        Rheinhessen
# 9    France                         Les Natures             Alsace

# %%
reviews [reviews.country == "Italy"]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 22       Italy  Delicate aromas recall white flower and citrus...
# 24       Italy  Aromas of prune, blackcurrant, toast and oak c...
# 26       Italy  Pretty aromas of yellow flower and stone fruit...
# 27       Italy  Aromas recall ripe dark berry, toast and a whi...
# 28       Italy  Aromas suggest mature berry, scorched earth, a...
# 31       Italy  Merlot and Nero d'Avola form the base for this...
# 32       Italy  Part of the extended Calanìca series, this Gri...
# 37       Italy  This concentrated Cabernet offers aromas of cu...
# 38       Italy  Inky in color, this wine has plump aromas of r...
# 39       Italy  Part of the natural wine movement, this wine i...
# ...

# %%
reviews.loc[reviews.country == "Italy", ["price","winery"]]
# Out:
#         price                           winery
# 0         NaN                          Nicosia
# 6        16.0                  Terre di Giurfo
# 13        NaN              Masseria Setteporte
# 22       19.0               Baglio di Pianetto
# 24       35.0                        Canicattì
# 26       13.0                         Stemmari
# 27       10.0                         Stemmari
# 28       17.0                  Terre di Giurfo
# 31        NaN               Duca di Salaparuta
# 32        NaN               Duca di Salaparuta
# 37       21.0              Feudi del Pisciotto
# 38       11.0             Feudi di San Marzano
# 39       12.0             Feudo di Santa Tresa
# 40       17.0                    Feudo Montoni
# 46       13.0                 Tasca d'Almerita
# 50        NaN  Viticultori Associati Canicatti
# 52       14.0             Cantine di Dolianova
# 54        NaN                            Corvo
# 57       13.0                 Tasca d'Almerita
# ...

# %%
reviews.loc[(reviews.points>95) & (reviews.country.isin(["Australia","US"]))]
# Out:
#           country                                        description  \
# 345     Australia  This wine contains some material over 100 year...
# 346     Australia  This deep brown wine smells like a damp, mossy...
# 348     Australia  Deep mahogany. Dried fig and black tea on the ...
# 349     Australia  RunRig is always complex, and the 2012 doesn't...
# 352            US  Citrus-kissed saltiness lies at the core of th...
# 355            US  A waft of smoky char and toasty oak provide a ...
# 1556           US  The flagship wine from Quilceda Creek offers e...
# 1557           US  A stupendous Pinot Noir, showing how beautiful...
# 1560           US  A stunning Pirouette—63% Cabernet Sauvignon, 2...
# 1565           US  An outstanding wine, the best California Caber...
# 1567           US  A drop-dead gorgeous Pinot Noir that will sati...
# 1574           US  A huge Cabernet, in the best sense of the word...
# 1577           US  A triumph, one of the greatest Riverblock bott...
# ...

# %%
reviews.loc[(reviews.country=='South Africa') & (reviews.price < 100), ['price','winery']]
# Out:
#         price                  winery
# 125      45.0                Le Riche
# 129      25.0               Camberley
# 132      30.0                 Delheim
# 197      23.0                   Spier
# 208      40.0           Delaire Graff
# 210      20.0                Eikendal
# 225      25.0               Oldenburg
# 226      20.0               Oldenburg
# 256      20.0  Goats do Roam Wine Co.
# 257      18.0             Graham Beck
# 258      35.0              Hartenberg
# 264      19.0                  Jardin
# 265      40.0                  Jardin
# 483      12.0               Cape View
# 484      12.0           Ken Forrester
# 657      50.0          Fable Mountain
# 694      50.0                 Reyneke
# 699      40.0                Kanonkop
# 1063     20.0                 Ormonde
# 1242     17.0            Danie de Wet
# 1245     35.0             Mulderbosch
# 1247     13.0  Rietvallei Estate Wine
# 1255     15.0           Guardian Peak
# 1389     16.0            Terre Brûlée
# ...

# %%
reviews.describe()
# Out:
#               points          price
# count  129971.000000  120975.000000
# mean       88.447138      35.363389
# std         3.039730      41.022218
# min        80.000000       4.000000
# 25%        86.000000      17.000000
# 50%        88.000000      25.000000
# 75%        91.000000      42.000000
# max       100.000000    3300.000000

# %%
countries = reviews.country.unique()

# %%
countries
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %%
count_countries = reviews.country.value_counts()

# %%
count_countries
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %%
ratio = reviews.points/reviews.price

# %%
bargain = ratio.idxmax()

# %%
reviews.loc[bargain,['title','country']]
# Out:
# title      Bandit NV Merlot (California)
# country                               US
# Name: 64590, dtype: object

# %%
reviews.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %%
tasters = reviews.taster_name.unique()
tasters
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
tasters_no = reviews.taster_name.value_counts()

# %%
tasters_no
# Out:
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %%
reviews.groupby(["country","province"]).points.max()
# Out:
# country    province
# Argentina  Mendoza Province        97
#            Other                   95
# Armenia    Armenia                 88
# Australia  Australia Other         93
#            New South Wales         94
#            South Australia         99
#            Tasmania                94
#            Victoria               100
#            Western Australia       95
# Austria    Austria                 93
#            Burgenland              98
#            Carnuntum               95
#            Eisenberg               95
#            Kamptal                 96
#            Kremstal                96
#            Leithaberg              94
#            Mittelburgenland        92
#            Neusiedlersee           91
#            Niederösterreich        96
#            Steiermark              90
#            Südburgenland           95
#            Südoststeiermark        94
#            Südsteiermark           94
#            Thermenregion           96
# ...

# %%
reviews.groupby(['country','province']).apply(lambda df:df.loc[df.points.idxmax, ['title']])
# Out:
#                                                                            title
# country   province
# Argentina Mendoza Province     Bodega Catena Zapata 2006 Nicasia Vineyard Mal...
#           Other                               Colomé 2010 Reserva Malbec (Salta)
# Armenia   Armenia                    Van Ardi 2015 Estate Bottled Rosé (Armenia)
# Australia Australia Other      Marquis Philips 2000 Sarah's Blend Red (South ...
#           New South Wales      De Bortoli 2007 Noble One Bortytis Semillon (N...
#           South Australia          Penfolds 2010 Grange Shiraz (South Australia)
#           Tasmania                          Tolpuddle 2014 Chardonnay (Tasmania)
#           Victoria             Chambers Rosewood Vineyards NV Rare Muscat (Ru...
#           Western Australia    Moss Wood 2011 Cabernet Sauvignon (Margaret Ri...
# Austria   Austria              Kracher NV Nouvelle Vague Nummer 4 Kollektion ...
# ...

# %%
reviews.groupby(["taster_name"]).count()
# Out:
#                     country  description  designation  points  price  \
# taster_name
# Alexander Peartree      415          415          268     415    413
# Anna Lee C. Iijima     4415         4415         3508    4415   4369
# Anne Krebiehl MW       3676         3685         3130    3685   3398
# Carrie Dykes            139          139           96     139    138
# Christina Pickard         6            6            2       6      6
# Fiona Adams              27           27           17      27     27
# Jeff Jenssen            469          491          383     491    491
# Jim Gordon             4177         4177         2660    4177   4171
# Joe Czerwinski         5145         5147         3428    5147   5012
# Kerin O’Keefe         10776        10776         7549   10776   9874
# Lauren Buzzeo          1832         1835         1268    1835   1713
# Matt Kettmann          6332         6332         4568    6332   6237
# ...

# %%
reviews.groupby(['price']).apply(lambda df:df.loc[df.price.idxmax, ['title']])
# Out:
#                                                     title
# price
# 4.0     Felix Solis 2013 Flirty Bird Syrah (Vino de la...
# 5.0     Herdade dos Machados 2009 Morgado da Canita Re...
# 6.0     Adega Cooperativa de Borba 2016 Brado Branco W...
# 7.0                 Cramele Recas 2009 Chardonnay (Recas)
# 8.0     Casca Wines 2015 Bote Chardonnay-Fernão Pires-...
# 9.0                Henry Fessy 2012 Nouveau  (Beaujolais)
# 10.0         Stemmari 2013 Nero d'Avola (Terre Siciliane)
# 11.0    Feudi di San Marzano 2011 I Tratturi Primitivo...
# 12.0    Heinz Eifel 2013 Shine Gewürztraminer (Rheinhe...
# 13.0    St. Julian 2013 Reserve Late Harvest Riesling ...
# 14.0        Rainstorm 2013 Pinot Gris (Willamette Valley)
# 15.0        Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 16.0     Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# 17.0    Terre di Giurfo 2011 Mascaria Barricato  (Cera...
# 18.0    Yalumba 2016 Made With Organic Grapes Chardonn...
# ...

# %%
reviews.groupby(["variety"]).price.agg([min,max])
# Out:
#                          min    max
# variety
# Abouriou                15.0   75.0
# Agiorgitiko             10.0   66.0
# Aglianico                6.0  180.0
# Aidani                  27.0   27.0
# Airen                    8.0   10.0
# Albana                  12.0   50.0
# Albanello               20.0   20.0
# Albariño                10.0   75.0
# Albarossa               40.0   40.0
# Aleatico                25.0   55.0
# Alfrocheiro             11.0   50.0
# Alicante                10.0   30.0
# Alicante Bouschet        7.0  150.0
# Aligoté                 13.0   36.0
# Alsace white blend      10.0   98.0
# Altesse                 15.0   19.0
# Alvarelhão              18.0   24.0
# Alvarinho                9.0   75.0
# Alvarinho-Chardonnay     9.0   15.0
# Ansonica                22.0   30.0
# Antão Vaz               11.0   30.0
# Apple                   25.0   33.0
# Aragonez                10.0   35.0
# Aragonês                14.0   70.0
# Argaman                 36.0   48.0
# ...

# %%
reviews.isnull
# Out:
# <bound method DataFrame.isnull of             country                                        description  \
# 0             Italy  Aromas include tropical fruit, broom, brimston...
# 1          Portugal  This is ripe and fruity, a wine that is smooth...
# 2                US  Tart and snappy, the flavors of lime flesh and...
# 3                US  Pineapple rind, lemon pith and orange blossom ...
# 4                US  Much like the regular bottling from 2012, this...
# 5             Spain  Blackberry and raspberry aromas show a typical...
# 6             Italy  Here's a bright, informal red that opens with ...
# 7            France  This dry and restrained wine offers spice in p...
# 8           Germany  Savory dried thyme notes accent sunnier flavor...
# 9            France  This has great depth of flavor with its fresh ...
# 10               US  Soft, supple plum envelopes an oaky structure ...
# 11           France  This is a dry wine, very spicy, with a tight, ...
# ...

# %%
reviews.notnull
# Out:
# <bound method DataFrame.notnull of             country                                        description  \
# 0             Italy  Aromas include tropical fruit, broom, brimston...
# 1          Portugal  This is ripe and fruity, a wine that is smooth...
# 2                US  Tart and snappy, the flavors of lime flesh and...
# 3                US  Pineapple rind, lemon pith and orange blossom ...
# 4                US  Much like the regular bottling from 2012, this...
# 5             Spain  Blackberry and raspberry aromas show a typical...
# 6             Italy  Here's a bright, informal red that opens with ...
# 7            France  This dry and restrained wine offers spice in p...
# 8           Germany  Savory dried thyme notes accent sunnier flavor...
# 9            France  This has great depth of flavor with its fresh ...
# 10               US  Soft, supple plum envelopes an oaky structure ...
# 11           France  This is a dry wine, very spicy, with a tight, ...
# ...

# %%
reviews.region_2.fillna("Unknown")
# Out:
# 0                   Unknown
# 1                   Unknown
# 2         Willamette Valley
# 3                   Unknown
# 4         Willamette Valley
# 5                   Unknown
# 6                   Unknown
# 7                   Unknown
# 8                   Unknown
# 9                   Unknown
# 10                     Napa
# 11                  Unknown
# 12                   Sonoma
# 13                  Unknown
# 14            Central Coast
# 15                  Unknown
# 16                  Unknown
# 17                  Unknown
# 18                  Unknown
# 19                  Unknown
# 20                  Unknown
# 21             Oregon Other
# 22                  Unknown
# 23            Central Coast
# 24                  Unknown
# 25                   Sonoma
# 26                  Unknown
# 27                  Unknown
# 28                  Unknown
# 29           Central Valley
#                 ...
# 129941              Unknown
# 129942               Sonoma
# ...

# %%
reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerina")
# Out:
# 0                @kerina
# 1             @vossroger
# 2            @paulgwine
# 3                    NaN
# 4            @paulgwine
# 5            @wineschach
# 6                @kerina
# 7             @vossroger
# 8                    NaN
# 9             @vossroger
# 10               @vboone
# 11            @vossroger
# 12               @vboone
# 13               @kerina
# 14         @mattkettmann
# 15                   NaN
# 16           @wineschach
# 17           @wineschach
# 18           @wineschach
# 19                   NaN
# 20                   NaN
# 21           @paulgwine
# 22               @kerina
# 23         @mattkettmann
# 24               @kerina
# 25               @vboone
# 26               @kerina
# 27               @kerina
# 28               @kerina
# 29               @vboone
#                ...
# 129941           @vboone
# 129942           @vboone
# 129943           @kerina
# 129944    @worldwineguys
# 129945     @mattkettmann
# 129946               NaN
# ...
